# %% [markdown]
# <a href="https://colab.research.google.com/github/anaya012391/CAPM-Analysis-Excel/blob/main/CAPM_Data_Collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the pandas library, which is used for data manipulation and analysis.
import pandas as pd
import numpy as np

# Download financial data
import yfinance as yf

# %%
tickers =["PG", "AAPL", "JPM", "XOM", "JNJ", "KO", "^GSPC"]
data = yf.download (
    tickers,
    start="2021-08-01",
    end="2026-08-01",
    interval="1mo",
    auto_adjust=False
)
# Out:
# [*********************100%***********************]  7 of 7 completed

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 60 entries, 2021-08-01 to 2026-07-01
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Adj Close, AAPL)   60 non-null     float64
#  1   (Adj Close, JNJ)    60 non-null     float64
#  2   (Adj Close, JPM)    60 non-null     float64
#  3   (Adj Close, KO)     60 non-null     float64
#  4   (Adj Close, PG)     60 non-null     float64
#  5   (Adj Close, XOM)    60 non-null     float64
#  6   (Adj Close, ^GSPC)  60 non-null     float64
#  7   (Close, AAPL)       60 non-null     float64
#  8   (Close, JNJ)        60 non-null     float64
#  9   (Close, JPM)        60 non-null     float64
#  10  (Close, KO)         60 non-null     float64
#  11  (Close, PG)         60 non-null     float64
#  12  (Close, XOM)        60 non-null     float64
#  13  (Close, ^GSPC)      60 non-null     float64
#  14  (High, AAPL)        60 non-null     float64
# ...

# %%
data.describe()
# Out:
# Price    Adj Close                                                             \
# Ticker        AAPL         JNJ         JPM         KO          PG         XOM
# count    60.000000   60.000000   60.000000  60.000000   60.000000   60.000000
# mean    198.568524  163.169894  194.633535  60.955036  143.835788  100.266835
# std      47.806335   31.518373   75.362953   9.318903   12.916698   25.392921
# min     127.651512  135.518723   94.846558  45.597359  113.686081   45.754665
# 25%     161.486408  145.774609  130.632847  54.759011  135.584328   91.734438
# 50%     188.936569  151.368111  170.993149  57.357244  144.035721  100.900795
# 75%     232.039143  160.080067  258.208458  68.282372  152.841328  110.042263
# max     311.791107  256.350006  351.790009  87.589996  170.843185  167.432053
#
# Price                     Close                          ...        Open  \
# Ticker        ^GSPC        AAPL         JNJ         JPM  ...          PG
# ...

# %%
adjusted_close = data["Adj Close"].copy()

adjusted_close = adjusted_close.reset_index()

# %%
adjusted_close.head()
# Out:
# Ticker       Date        AAPL         JNJ         JPM         KO          PG  \
# 0      2021-08-01  148.090591  151.309784  141.140900  48.567837  125.225510
# 1      2021-09-01  138.015015  141.145584  144.441101  45.597359  122.947731
# 2      2021-10-01  146.110580  142.351654  150.815369  48.986523  126.532784
# 3      2021-11-01  161.464172  137.170212  140.997147  45.933441  127.939766
# 4      2021-12-01  173.449432  150.488739  140.571014  51.853554  144.752975
#
# Ticker        XOM        ^GSPC
# 0       45.754665  4522.680176
# 1       49.363342  4307.540039
# 2       54.104973  4605.379883
# 3       50.894268  4567.000000
# 4       52.042450  4766.180176

# %%
adjusted_close
# Out:
# Ticker       Date        AAPL         JNJ         JPM         KO          PG  \
# 0      2021-08-01  148.090591  151.309784  141.140900  48.567837  125.225510
# 1      2021-09-01  138.015015  141.145584  144.441101  45.597359  122.947731
# 2      2021-10-01  146.110580  142.351654  150.815369  48.986523  126.532784
# 3      2021-11-01  161.464172  137.170212  140.997147  45.933441  127.939766
# 4      2021-12-01  173.449432  150.488739  140.571014  51.853554  144.752975
# 5      2022-01-01  170.724182  151.561920  132.706467  53.429920  142.749847
# 6      2022-02-01  161.493820  145.700073  126.633743  54.507103  138.692871
# 7      2022-03-01  170.775406  156.908417  121.739861  54.712551  135.943756
# 8      2022-04-01  154.187866  159.768082  107.383942  57.015774  143.640182
# 9      2022-05-01  145.785202  159.966080  118.962624  55.930344  132.304626
# 10     2022-06-01  133.913956  158.166183  101.311211  55.916683  128.645370
# ...
